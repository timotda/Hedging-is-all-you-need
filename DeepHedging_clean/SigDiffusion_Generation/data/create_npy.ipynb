# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/Users/timot/Desktop/SigDiffusions/market_data.csv' )
aapl = pd.DataFrame(df['AAPL'])
arr = aapl.to_numpy()
np.save("/Users/timot/Desktop/SigDiffusions/data/AAPL.npy", arr)
